# %%
import pandas as pd

# %%
pd.read_csv("C:\Users\isubh\OneDrive\Desktop\cars_sampled.csv")
# Out:
#   Cell In[3], line 1
#     pd.read_csv("C:\Users\isubh\OneDrive\Desktop\cars_sampled.csv")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pd.read_csv("C:/Users\isubh\OneDrive\Desktop\cars_sampled.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\isubh\AppData\Local\Temp\ipykernel_13296\2122487696.py:1: SyntaxWarning: invalid escape sequence '\i'
#   pd.read_csv("C:/Users\isubh\OneDrive\Desktop\cars_sampled.csv")
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1         7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2         1/4/2016 0:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# ...

# %%
df=pd.read_csv("C:/Users/isubh/OneDrive/Desktop/cars_sampled.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (50001, 19)

# %%
df.head(10)
# Out:
#         dateCrawled                                               name  \
# 0  30/03/2016 13:51                                       Zu_verkaufen
# 1     7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2     1/4/2016 0:57                                  Volkswagen_Touran
# 3  19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4  16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# 5    2/4/2016 12:51           VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 6    3/4/2016 11:06                                         Opel_astra
# 7  24/03/2016 15:52                        Mercedes_Benz_CLK_Coupe_200
# 8  28/03/2016 14:40  Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...
# 9    5/4/2016 11:38                 Skoda_Octavia_2.0_TDI_DSG_Elegance
#
#     seller offerType  price   abtest    vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test      limousine                2003
# ...

# %%
df.tail(10)
# Out:
#             dateCrawled                                               name  \
# 49991   10/3/2016 23:36                                        BMW_X3_3.0i
# 49992  14/03/2016 13:57                         Opel_Astra_2.0_DI_Elegance
# 49993  14/03/2016 11:37       Renault_Clio_mit_Servolenkung_und_neuem_TÜV!
# 49994     9/3/2016 1:36                                        Porsche_993
# 49995  23/03/2016 21:45  Opel_Astra_G_Caravan__Tuev_2/2018__Scheckheft_...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType   price   abtest    vehicleType  \
# 49991     private     offer   10900     test      limousine
# ...

# %%
df.iloc[5:,:]
# Out:
#             dateCrawled                                               name  \
# 5        2/4/2016 12:51           VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 6        3/4/2016 11:06                                         Opel_astra
# 7      24/03/2016 15:52                        Mercedes_Benz_CLK_Coupe_200
# 8      28/03/2016 14:40  Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...
# 9        5/4/2016 11:38                 Skoda_Octavia_2.0_TDI_DSG_Elegance
# ...                 ...                                                ...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# ...

# %%
df.iloc[:,5:]
# Out:
#         abtest    vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         test      limousine                2003     manual      150
# 1      control            suv                2005     manual      163
# 2         test            bus                2003     manual      101
# 3      control      small car                2006     manual       86
# 4         test            suv                2008  automatic      185
# ...        ...            ...                 ...        ...      ...
# 49996     test            bus                2005        NaN        0
# 49997  control            NaN                1990        NaN        0
# 49998     test          coupe                2004     manual        0
# 49999  control  station wagon                2000     manual        0
# 50000     test      small car                2006     manual       38
#
#              model  kilometer  monthOfRegistration fuelType       brand  \
# ...

# %%
df.iloc[:5,:]
# Out:
#         dateCrawled                                               name  \
# 0  30/03/2016 13:51                                       Zu_verkaufen
# 1     7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2     1/4/2016 0:57                                  Volkswagen_Touran
# 3  19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4  16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
#
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
df.loc[5:,:]
# Out:
#             dateCrawled                                               name  \
# 5        2/4/2016 12:51           VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 6        3/4/2016 11:06                                         Opel_astra
# 7      24/03/2016 15:52                        Mercedes_Benz_CLK_Coupe_200
# 8      28/03/2016 14:40  Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...
# 9        5/4/2016 11:38                 Skoda_Octavia_2.0_TDI_DSG_Elegance
# ...                 ...                                                ...
# 49996    3/4/2016 15:48                               Suche_VW_T5_Multivan
# 49997  27/03/2016 14:55  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60
# 49998  14/03/2016 18:51  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...
# 49999  15/03/2016 18:06        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 50000   22/03/2016 9:54                    Chevrolet_Matiz_1.Hd_TÜV11/2017
#
#            seller offerType  price   abtest    vehicleType  \
# ...

# %%
df.loc[5:20,:]
# Out:
#          dateCrawled                                               name  \
# 5     2/4/2016 12:51           VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 6     3/4/2016 11:06                                         Opel_astra
# 7   24/03/2016 15:52                        Mercedes_Benz_CLK_Coupe_200
# 8   28/03/2016 14:40  Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...
# 9     5/4/2016 11:38                 Skoda_Octavia_2.0_TDI_DSG_Elegance
# 10   21/03/2016 9:52                        Mercedes_Benz_A_140_Classic
# 11  25/03/2016 12:40                                  Opel_Astra___G_CC
# 12   13/03/2016 7:52  Toyota_Yaris_1.0_linea_sol___Klima___Standheizung
# 13  21/03/2016 18:56                     BMW_e46_316ti_Compact__M_Paket
# 14    8/3/2016 20:52                Schoen_klein_wagen__119000__Org.Klm
# 15    2/4/2016 13:44             Volvo_V70_Kombi_Diesel_2_5_TÜV_03/2018
# 16   12/3/2016 21:52                                  Nissan_Terrano_II
# ...

# %%
df.loc[5:20,"name"]
# Out:
# 5              VW_Passat_35i_Facelift_Limousine_TÜV_Neu
# 6                                            Opel_astra
# 7                           Mercedes_Benz_CLK_Coupe_200
# 8     Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...
# 9                    Skoda_Octavia_2.0_TDI_DSG_Elegance
# 10                          Mercedes_Benz_A_140_Classic
# 11                                    Opel_Astra___G_CC
# 12    Toyota_Yaris_1.0_linea_sol___Klima___Standheizung
# 13                       BMW_e46_316ti_Compact__M_Paket
# 14                  Schoen_klein_wagen__119000__Org.Klm
# 15               Volvo_V70_Kombi_Diesel_2_5_TÜV_03/2018
# 16                                    Nissan_Terrano_II
# 17                                         Iveco_KASTEN
# 18                               Verkaufe_Golf_4_defekt
# 19            Golf_3_mit_tuev_anfaenger_winter_fahrzeug
# 20    Selten_gewordener_Youngtimer_Mazda_323_f_BG_mi...
# Name: name, dtype: object

# %%
df.loc[5:20,"name","vehicleType"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.loc[5:20,"name","vehicleType"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1371, in _LocIndexer._getitem_tuple(self, tup)
#    1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
# -> 1371 tup = self._validate_tuple_indexer(tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
#
# ...

# %%
df.loc[5:20,["name","vehicleType"]]
# Out:
#                                                  name    vehicleType
# 5            VW_Passat_35i_Facelift_Limousine_TÜV_Neu      limousine
# 6                                          Opel_astra  station wagon
# 7                         Mercedes_Benz_CLK_Coupe_200          coupe
# 8   Vectra_C_Caravan_1_8_Edition_Facelift_m_AHK_In...  station wagon
# 9                  Skoda_Octavia_2.0_TDI_DSG_Elegance      limousine
# 10                        Mercedes_Benz_A_140_Classic      limousine
# 11                                  Opel_Astra___G_CC          coupe
# 12  Toyota_Yaris_1.0_linea_sol___Klima___Standheizung      small car
# 13                     BMW_e46_316ti_Compact__M_Paket            NaN
# 14                Schoen_klein_wagen__119000__Org.Klm      limousine
# 15             Volvo_V70_Kombi_Diesel_2_5_TÜV_03/2018  station wagon
# 16                                  Nissan_Terrano_II            suv
# 17                                       Iveco_KASTEN         others
# ...

# %%
df.loc[:,"vehicleType"]
# Out:
# 0            limousine
# 1                  suv
# 2                  bus
# 3            small car
# 4                  suv
#              ...
# 49996              bus
# 49997              NaN
# 49998            coupe
# 49999    station wagon
# 50000        small car
# Name: vehicleType, Length: 50001, dtype: object

# %%
df["vehicleType"]
# Out:
# 0            limousine
# 1                  suv
# 2                  bus
# 3            small car
# 4                  suv
#              ...
# 49996              bus
# 49997              NaN
# 49998            coupe
# 49999    station wagon
# 50000        small car
# Name: vehicleType, Length: 50001, dtype: object

# %%
df[["name","vehicleType"]]
# Out:
#                                                     name    vehicleType
# 0                                           Zu_verkaufen      limousine
# 1                                 Volvo_XC90_2.4D_Summum            suv
# 2                                      Volkswagen_Touran            bus
# 3                           Seat_Ibiza_1.4_16V_Reference      small car
# 4      Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...            suv
# ...                                                  ...            ...
# 49996                               Suche_VW_T5_Multivan            bus
# 49997  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60            NaN
# 49998  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...          coupe
# 49999        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten  station wagon
# 50000                    Chevrolet_Matiz_1.Hd_TÜV11/2017      small car
#
# [50001 rows x 2 columns]

# %%
type(df[["price","abtest"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["price"])
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series(["Sachin Tendulkar","Rahul Dravid"])
s1
s2=pd.Series(["Shane Bond", "Brett Lee"])
s2
# Out:
# 0    Shane Bond
# 1     Brett Lee
# dtype: object

# %%
pd.DataFrame([s1,s2])
# Out:
#                   0             1
# 0  Sachin Tendulkar  Rahul Dravid
# 1        Shane Bond     Brett Lee

# %%
ff=pd.DataFrame(
    [
        [1,2],
        ["Sachin","Rahul"]
    ],
    columns=["first","second"],
    index=["row1","row2"]
)
ff.transpose()
# Out:
#        row1    row2
# first     1  Sachin
# second    2   Rahul

# %%
ff.count()
# Out:
# first     2
# second    2
# dtype: int64

# %%
df[["name","vehicleType"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 df[["name","vehicleType"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df=pd.read_csv("C:/Users/isubh/OneDrive/Desktop/cars_sampled.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.count()
# Out:
# dateCrawled            50001
# name                   50001
# seller                 50001
# offerType              50001
# price                  50001
# abtest                 50001
# vehicleType            44813
# yearOfRegistration     50001
# gearbox                47177
# powerPS                50001
# model                  47243
# kilometer              50001
# monthOfRegistration    50001
# fuelType               45498
# brand                  50001
# notRepairedDamage      40285
# dateCreated            50001
# postalCode             50001
# lastSeen               50001
# dtype: int64

# %%
df.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 df.max()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11656, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11648 @doc(make_doc("max", ndim=2))
#   11649 def max(
#   11650     self,
#    (...)
#   11654     **kwargs,
#   11655 ):
# > 11656     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11657     if isinstance(result, Series):
#   11658         result = result.__finalize__(self, method="max")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12404, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12397 def max(
#   12398     self,
#   12399     axis: Axis | None = 0,
#    (...)
#   12402     **kwargs,
#   12403 ):
# > 12404     return self._stat_function(
#   12405         "max",
#   12406         nanops.nanmax,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50001 non-null  object
#  1   name                 50001 non-null  object
#  2   seller               50001 non-null  object
#  3   offerType            50001 non-null  object
#  4   price                50001 non-null  int64
#  5   abtest               50001 non-null  object
#  6   vehicleType          44813 non-null  object
#  7   yearOfRegistration   50001 non-null  int64
#  8   gearbox              47177 non-null  object
#  9   powerPS              50001 non-null  int64
#  10  model                47243 non-null  object
#  11  kilometer            50001 non-null  int64
#  12  monthOfRegistration  50001 non-null  int64
#  13  fuelType             45498 non-null  object
#  14  brand                50001 non-null  object
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...
